# %%
#@title ### 1. Install Files

# %cd /content/
# !apt install -y -qq aria2
# !aria2c --summary-interval=5 -x 3 --allow-overwrite=true -Z \
   https://pub-2fdef7a2969f43289c42ac5ae3412fd4.r2.dev/naifu.tar \
   https://pub-2fdef7a2969f43289c42ac5ae3412fd4.r2.dev/animefull-latest.tar
  
# !echo "Decompressing..."
# !tar xf naifu.tar && rm naifu.tar
# !echo "Done."

# %cd /content/naifu
# !pip install virtualenv && bash ./setup.sh
# !curl -Ls https://github.com/ekzhang/bore/releases/download/v0.4.0/bore-v0.4.0-x86_64-unknown-linux-musl.tar.gz | tar zx -C /usr/bin
# !curl -Lo /usr/bin/cloudflared https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64 && chmod +x /usr/bin/cloudflared
# Out:
# /content
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# The following additional packages will be installed:
#   libc-ares2
# The following NEW packages will be installed:
#   aria2 libc-ares2
# 0 upgraded, 2 newly installed, 0 to remove and 27 not upgraded.
# Need to get 1,274 kB of archives.
# After this operation, 4,912 kB of additional disk space will be used.
# Selecting previously unselected package libc-ares2:amd64.
# (Reading database ... 123942 files and directories currently installed.)
# Preparing to unpack .../libc-ares2_1.14.0-1ubuntu0.1_amd64.deb ...
# Unpacking libc-ares2:amd64 (1.14.0-1ubuntu0.1) ...
# Selecting previously unselected package aria2.
# Preparing to unpack .../aria2_1.33.1-1_amd64.deb ...
# Unpacking aria2 (1.33.1-1) ...
# Setting up libc-ares2:amd64 (1.14.0-1ubuntu0.1) ...
# Setting up aria2 (1.33.1-1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.6) ...
#
# 10/25 05:50:20 [NOTICE] Downloading 2 item(s)
#  *** Download Progress Summary as of Tue Oct 25 05:50:26 2022 ***
# =
# [#3529a3 394MiB/7.4GiB(5%) CN:3 DL:72MiB ETA:1m39s]
# FILE: /content/naifu.tar
# -
# [#c390bc 277MiB/7.1GiB(3%) CN:3 DL:64MiB ETA:1m50s]
# FILE: /content/animefull-latest.tar
# -
#
#  *** Download Progress Summary as of Tue Oct 25 05:50:32 2022 ***
# =
# [#3529a3 884MiB/7.4GiB(11%) CN:3 DL:80MiB ETA:1m23s]
# FILE: /content/naifu.tar
# -
# [#c390bc 699MiB/7.1GiB(9%) CN:3 DL:71MiB ETA:1m33s]
# FILE: /content/animefull-latest.tar
# -
#
#  *** Download Progress Summary as of Tue Oct 25 05:50:38 2022 ***
# =
# [#3529a3 1.3GiB/7.4GiB(17%) CN:3 DL:79MiB ETA:1m18s]
# FILE: /content/naifu.tar
# -
# [#c390bc 1.1GiB/7.1GiB(15%) CN:3 DL:71MiB ETA:1m27s]
# FILE: /content/animefull-latest.tar
# -
#
#  *** Download Progress Summary as of Tue Oct 25 05:50:44 2022 ***
# =
# [#3529a3 1.7GiB/7.4GiB(24%) CN:3 DL:81MiB ETA:1m10s]
# FILE: /content/naifu.tar
# -
# [#c390bc 1.5GiB/7.1GiB(21%) CN:3 DL:70MiB ETA:1m21s]
# FILE: /content/animefull-latest.tar
# -
#
#  *** Download Progress Summary as of Tue Oct 25 05:50:50 2022 ***
# =
# [#3529a3 2.2GiB/7.4GiB(30%) CN:3 DL:79MiB ETA:1m6s]
# FILE: /content/naifu.tar
# -
# [#c390bc 1.9GiB/7.1GiB(26%) CN:3 DL:69MiB ETA:1m16s]
# FILE: /content/animefull-latest.tar
# -
#
#  *** Download Progress Summary as of Tue Oct 25 05:50:56 2022 ***
# =
# [#3529a3 2.6GiB/7.4GiB(35%) CN:3 DL:72MiB ETA:1m7s]
# FILE: /content/naifu.tar
# -
# [#c390bc 2.3GiB/7.1GiB(32%) CN:3 DL:65MiB ETA:1m15s]
# FILE: /content/animefull-latest.tar
# -
#
#  *** Download Progress Summary as of Tue Oct 25 05:51:02 2022 ***
# =
# [#3529a3 3.0GiB/7.4GiB(41%) CN:3 DL:71MiB ETA:1m2s]
# FILE: /content/naifu.tar
# -
# [#c390bc 2.7GiB/7.1GiB(37%) CN:3 DL:70MiB ETA:1m4s]
# FILE: /content/animefull-latest.tar
# -
#
#  *** Download Progress Summary as of Tue Oct 25 05:51:08 2022 ***
# =
# [#3529a3 3.5GiB/7.4GiB(47%) CN:3 DL:75MiB ETA:52s]
# FILE: /content/naifu.tar
# -
# [#c390bc 3.1GiB/7.1GiB(44%) CN:3 DL:74MiB ETA:55s]
# FILE: /content/animefull-latest.tar
# -
#
#  *** Download Progress Summary as of Tue Oct 25 05:51:13 2022 ***
# =
# [#3529a3 3.7GiB/7.4GiB(51%) CN:3 DL:64MiB ETA:57s]
# FILE: /content/naifu.tar
# -
# [#c390bc 3.4GiB/7.1GiB(47%) CN:3 DL:65MiB ETA:58s]
# FILE: /content/animefull-latest.tar
# -
#
#  *** Download Progress Summary as of Tue Oct 25 05:51:19 2022 ***
# =
# [#3529a3 4.2GiB/7.4GiB(57%) CN:3 DL:66MiB ETA:49s]
# FILE: /content/naifu.tar
# -
# [#c390bc 3.8GiB/7.1GiB(54%) CN:3 DL:66MiB ETA:50s]
# FILE: /content/animefull-latest.tar
# -
#
#  *** Download Progress Summary as of Tue Oct 25 05:51:25 2022 ***
# =
# [#3529a3 4.6GiB/7.4GiB(62%) CN:3 DL:75MiB ETA:37s]
# FILE: /content/naifu.tar
# -
# [#c390bc 4.3GiB/7.1GiB(60%) CN:3 DL:76MiB ETA:38s]
# FILE: /content/animefull-latest.tar
# -
#
#  *** Download Progress Summary as of Tue Oct 25 05:51:31 2022 ***
# =
# [#3529a3 5.1GiB/7.4GiB(68%) CN:3 DL:75MiB ETA:31s]
# FILE: /content/naifu.tar
# -
# [#c390bc 4.7GiB/7.1GiB(66%) CN:3 DL:75MiB ETA:32s]
# FILE: /content/animefull-latest.tar
# -
#
#  *** Download Progress Summary as of Tue Oct 25 05:51:37 2022 ***
# =
# [#3529a3 5.5GiB/7.4GiB(74%) CN:3 DL:75MiB ETA:25s]
# FILE: /content/naifu.tar
# -
# [#c390bc 5.2GiB/7.1GiB(72%) CN:3 DL:76MiB ETA:26s]
# FILE: /content/animefull-latest.tar
# -
#
#  *** Download Progress Summary as of Tue Oct 25 05:51:43 2022 ***
# =
# [#3529a3 5.9GiB/7.4GiB(80%) CN:3 DL:72MiB ETA:20s]
# FILE: /content/naifu.tar
# -
# [#c390bc 5.6GiB/7.1GiB(79%) CN:3 DL:81MiB ETA:18s]
# FILE: /content/animefull-latest.tar
# -
#
#  *** Download Progress Summary as of Tue Oct 25 05:51:49 2022 ***
# =
# [#3529a3 6.4GiB/7.4GiB(86%) CN:3 DL:75MiB ETA:13s]
# FILE: /content/naifu.tar
# -
# [#c390bc 6.1GiB/7.1GiB(85%) CN:3 DL:78MiB ETA:13s]
# FILE: /content/animefull-latest.tar
# -
#
#  *** Download Progress Summary as of Tue Oct 25 05:51:55 2022 ***
# =
# [#3529a3 6.8GiB/7.4GiB(92%) CN:3 DL:77MiB ETA:7s]
# FILE: /content/naifu.tar
# -
# [#c390bc 6.5GiB/7.1GiB(91%) CN:3 DL:75MiB ETA:8s]
# FILE: /content/animefull-latest.tar
# -
#
#  *** Download Progress Summary as of Tue Oct 25 05:52:00 2022 ***
# =
# [#3529a3 7.2GiB/7.4GiB(98%) CN:3 DL:74MiB ETA:1s]
# FILE: /content/naifu.tar
# -
# [#c390bc 7.0GiB/7.1GiB(98%) CN:3 DL:78MiB ETA:1s]
# FILE: /content/animefull-latest.tar
# -
#
#
# 10/25 05:52:02 [NOTICE] Download complete: /content/naifu.tar
#
# 10/25 05:52:03 [NOTICE] Download complete: /content/animefull-latest.tar
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 3529a3|OK  |    74MiB/s|/content/naifu.tar
# c390bc|OK  |    72MiB/s|/content/animefull-latest.tar
#
# Status Legend:
# (OK):download completed.
# Decompressing...
# Done.
# /content/naifu
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting virtualenv
#   Downloading virtualenv-20.16.5-py3-none-any.whl (8.8 MB)
#      |████████████████████████████████| 8.8 MB 5.3 MB/s
# Collecting platformdirs<3,>=2.4
#   Downloading platformdirs-2.5.2-py3-none-any.whl (14 kB)
# Requirement already satisfied: importlib-metadata>=4.8.3 in /usr/local/lib/python3.7/dist-packages (from virtualenv) (4.13.0)
# Requirement already satisfied: filelock<4,>=3.4.1 in /usr/local/lib/python3.7/dist-packages (from virtualenv) (3.8.0)
# Collecting distlib<1,>=0.3.5
#   Downloading distlib-0.3.6-py2.py3-none-any.whl (468 kB)
#      |████████████████████████████████| 468 kB 46.0 MB/s
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.8.3->virtualenv) (3.9.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.8.3->virtualenv) (4.1.1)
# Installing collected packages: platformdirs, distlib, virtualenv
# Successfully installed distlib-0.3.6 platformdirs-2.5.2 virtualenv-20.16.5
# + virtualenv venv
# created virtual environment CPython3.7.15.final.0-64 in 1318ms
#   creator CPython3Posix(dest=/content/naifu/venv, clear=False, no_vcs_ignore=False, global=False)
#   seeder FromAppData(download=False, pip=bundle, setuptools=bundle, wheel=bundle, via=copy, app_data_dir=/root/.local/share/virtualenv)
#     added seed packages: pip==22.2.2, setuptools==65.3.0, wheel==0.37.1
#   activators BashActivator,CShellActivator,FishActivator,NushellActivator,PowerShellActivator,PythonActivator
# + . venv/bin/activate
# ++ '[' venv/bin/activate = ./setup.sh ']'
# ++ deactivate nondestructive
# ++ unset -f pydoc
# ++ '[' -z '' ']'
# ++ '[' -z '' ']'
# ++ hash -r
# ++ '[' -z '' ']'
# ++ unset VIRTUAL_ENV
# ++ '[' '!' nondestructive = nondestructive ']'
# ++ VIRTUAL_ENV=/content/naifu/venv
# ++ '[' linux-gnu = cygwin ']'
# ++ '[' linux-gnu = msys ']'
# ++ export VIRTUAL_ENV
# ++ _OLD_VIRTUAL_PATH=/opt/bin:/usr/local/nvidia/bin:/usr/local/cuda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/tools/node/bin:/tools/google-cloud-sdk/bin
# ++ PATH=/content/naifu/venv/bin:/opt/bin:/usr/local/nvidia/bin:/usr/local/cuda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/tools/node/bin:/tools/google-cloud-sdk/bin
# ++ export PATH
# ++ '[' -z '' ']'
# ++ '[' -z '' ']'
# ++ _OLD_VIRTUAL_PS1=
# ++ '[' x '!=' x ']'
# +++ basename /content/naifu/venv
# ++ PS1='(venv) '
# ++ export PS1
# ++ alias pydoc
# ++ true
# ++ hash -r
# + pip install -r requirements.txt
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/, https://download.pytorch.org/whl/cu116
# Collecting torch
#   Downloading https://download.pytorch.org/whl/cu116/torch-1.12.1%2Bcu116-cp37-cp37m-linux_x86_64.whl (1904.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 1.9/1.9 GB 96.3 MB/s eta 0:00:01tcmalloc: large alloc 1904836608 bytes == 0x3a5e000 @  0x7fa5b161d1e7 0x4b2590 0x4b261c 0x58ead6 0x4f355e 0x4d222f 0x51041f 0x5b4ee6 0x58ff2e 0x50ca37 0x5b4ee6 0x58ff2e 0x50ca37 0x5b4ee6 0x58ff2e 0x50ca37 0x5b4ee6 0x58ff2e 0x50ca37 0x5b4ee6 0x58ff2e 0x50ca37 0x58fd37 0x50ca37 0x5b4ee6 0x58ff2e 0x50d482 0x5b4ee6 0x58ff2e 0x50ca37 0x5b4ee6
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 1.9/1.9 GB 92.6 MB/s eta 0:00:01tcmalloc: large alloc 2381045760 bytes == 0x752f6000 @  0x7fa5b161e615 0x58ead6 0x4f355e 0x4d222f 0x51041f 0x5b4ee6 0x58ff2e 0x50ca37 0x5b4ee6 0x58ff2e 0x50ca37 0x5b4ee6 0x58ff2e 0x50ca37 0x5b4ee6 0x58ff2e 0x50ca37 0x5b4ee6 0x58ff2e 0x50ca37 0x58fd37 0x50ca37 0x5b4ee6 0x58ff2e 0x50d482 0x5b4ee6 0x58ff2e 0x50ca37 0x5b4ee6 0x58ff2e 0x50ca37
# tcmalloc: large alloc 1904836608 bytes == 0x3a5e000 @  0x7fa5b161d1e7 0x4b2590 0x5ad01c 0x5ad387 0x4d222f 0x51041f 0x5b4ee6 0x58ff2e 0x50ca37 0x5b4ee6 0x58ff2e 0x50ca37 0x5b4ee6 0x4bad99 0x4d3249 0x591e56 0x5fbace 0x590ae5 0x510946 0x58fd37 0x510325 0x5b4ee6 0x58ff2e 0x510325 0x5b4ee6 0x58ff2e 0x50d482 0x4d00fb 0x50cb8d 0x4d00fb 0x50cb8d
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 GB 876.0 kB/s eta 0:00:00
# Collecting torchvision
#   Downloading https://download.pytorch.org/whl/cu116/torchvision-0.13.1%2Bcu116-cp37-cp37m-linux_x86_64.whl (23.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.5/23.5 MB 32.1 MB/s eta 0:00:00
# Collecting torchaudio
#   Downloading https://download.pytorch.org/whl/cu116/torchaudio-0.12.1%2Bcu116-cp37-cp37m-linux_x86_64.whl (3.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 27.1 MB/s eta 0:00:00
# Collecting dotmap
#   Downloading dotmap-1.3.30-py3-none-any.whl (11 kB)
# Collecting fastapi
#   Downloading fastapi-0.85.1-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.4/55.4 kB 3.4 MB/s eta 0:00:00
# Collecting uvicorn
#   Downloading uvicorn-0.19.0-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.6/56.6 kB 5.0 MB/s eta 0:00:00
# Collecting omegaconf
#   Downloading omegaconf-2.2.3-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.3/79.3 kB 8.3 MB/s eta 0:00:00
# Collecting transformers
#   Downloading transformers-4.23.1-py3-none-any.whl (5.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 30.2 MB/s eta 0:00:00
# Collecting sentence_transformers
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 8.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.7.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 42.8 MB/s eta 0:00:00
# Collecting einops
#   Downloading einops-0.5.0-py3-none-any.whl (36 kB)
# Collecting pytorch_lightning
#   Downloading pytorch_lightning-1.7.7-py3-none-any.whl (708 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 708.1/708.1 kB 8.3 MB/s eta 0:00:00
# Collecting ftfy
#   Downloading ftfy-6.1.1-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 5.2 MB/s eta 0:00:00
# Collecting scikit-image
#   Downloading scikit_image-0.19.3-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (13.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 40.1 MB/s eta 0:00:00
# Collecting torchdiffeq
#   Downloading torchdiffeq-0.2.3-py3-none-any.whl (31 kB)
# Collecting jsonmerge
#   Downloading jsonmerge-1.8.0.tar.gz (26 kB)
#   Preparing metadata (setup.py) ... done
# Collecting typing-extensions
#   Downloading typing_extensions-4.4.0-py3-none-any.whl (26 kB)
# Collecting requests
#   Downloading requests-2.28.1-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 7.5 MB/s eta 0:00:00
# Collecting numpy
#   Downloading numpy-1.21.6-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.7/15.7 MB 40.1 MB/s eta 0:00:00
# Collecting pillow!=8.3.*,>=5.3.0
#   Downloading Pillow-9.2.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 16.8 MB/s eta 0:00:00
# Collecting pydantic!=1.7,!=1.7.1,!=1.7.2,!=1.7.3,!=1.8,!=1.8.1,<2.0.0,>=1.6.2
#   Downloading pydantic-1.10.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 45.2 MB/s eta 0:00:00
# Collecting starlette==0.20.4
#   Downloading starlette-0.20.4-py3-none-any.whl (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.6/63.6 kB 7.0 MB/s eta 0:00:00
# Collecting anyio<5,>=3.4.0
#   Downloading anyio-3.6.2-py3-none-any.whl (80 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.6/80.6 kB 9.4 MB/s eta 0:00:00
# Collecting click>=7.0
#   Downloading click-8.1.3-py3-none-any.whl (96 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.6/96.6 kB 11.1 MB/s eta 0:00:00
# Collecting h11>=0.8
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 6.8 MB/s eta 0:00:00
# Collecting antlr4-python3-runtime==4.9.*
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 13.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting PyYAML>=5.1.0
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 596.3/596.3 kB 6.9 MB/s eta 0:00:00
# Collecting importlib-metadata
#   Downloading importlib_metadata-5.0.0-py3-none-any.whl (21 kB)
# Collecting filelock
#   Downloading filelock-3.8.0-py3-none-any.whl (10 kB)
# Collecting huggingface-hub<1.0,>=0.10.0
#   Downloading huggingface_hub-0.10.1-py3-none-any.whl (163 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.5/163.5 kB 15.4 MB/s eta 0:00:00
# Collecting packaging>=20.0
#   Downloading packaging-21.3-py3-none-any.whl (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.8/40.8 kB 4.6 MB/s eta 0:00:00
# Collecting regex!=2019.12.17
#   Downloading regex-2022.9.13-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (757 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 757.0/757.0 kB 8.5 MB/s eta 0:00:00
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 45.8 MB/s eta 0:00:00
# Collecting tqdm>=4.27
#   Downloading tqdm-4.64.1-py2.py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 8.0 MB/s eta 0:00:00
# Collecting scikit-learn
#   Downloading scikit_learn-1.0.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (24.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.8/24.8 MB 34.6 MB/s eta 0:00:00
# Collecting scipy
#   Downloading scipy-1.7.3-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (38.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.1/38.1 MB 13.2 MB/s eta 0:00:00
# Collecting nltk
#   Downloading nltk-3.7-py3-none-any.whl (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 16.6 MB/s eta 0:00:00
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.97-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 14.9 MB/s eta 0:00:00
# Collecting tensorboard>=2.9.1
#   Downloading tensorboard-2.10.1-py3-none-any.whl (5.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 48.9 MB/s eta 0:00:00
# Collecting torchmetrics>=0.7.0
#   Downloading torchmetrics-0.10.0-py3-none-any.whl (529 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 529.2/529.2 kB 5.9 MB/s eta 0:00:00
# Collecting pyDeprecate>=0.3.1
#   Downloading pyDeprecate-0.3.2-py3-none-any.whl (10 kB)
# Collecting fsspec[http]!=2021.06.0,>=2021.05.0
#   Downloading fsspec-2022.10.0-py3-none-any.whl (138 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.8/138.8 kB 14.9 MB/s eta 0:00:00
# Collecting wcwidth>=0.2.5
#   Downloading wcwidth-0.2.5-py2.py3-none-any.whl (30 kB)
# Collecting networkx>=2.2
#   Downloading networkx-2.6.3-py3-none-any.whl (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 17.6 MB/s eta 0:00:00
# Collecting PyWavelets>=1.1.1
#   Downloading PyWavelets-1.3.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.4/6.4 MB 39.9 MB/s eta 0:00:00
# Collecting imageio>=2.4.1
#   Downloading imageio-2.22.2-py3-none-any.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 26.6 MB/s eta 0:00:00
# Collecting tifffile>=2019.7.26
#   Downloading tifffile-2021.11.2-py3-none-any.whl (178 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.9/178.9 kB 15.9 MB/s eta 0:00:00
# Collecting jsonschema
#   Downloading jsonschema-4.16.0-py3-none-any.whl (83 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.1/83.1 kB 9.0 MB/s eta 0:00:00
# Collecting aiohttp!=4.0.0a0,!=4.0.0a1
#   Downloading aiohttp-3.8.3-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (948 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 948.0/948.0 kB 10.8 MB/s eta 0:00:00
# Collecting pyparsing!=3.0.5,>=2.0.2
#   Downloading pyparsing-3.0.9-py3-none-any.whl (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.3/98.3 kB 10.0 MB/s eta 0:00:00
# Collecting google-auth<3,>=1.6.3
#   Downloading google_auth-2.13.0-py2.py3-none-any.whl (174 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 174.5/174.5 kB 14.4 MB/s eta 0:00:00
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Collecting protobuf<3.20,>=3.9.2
#   Downloading protobuf-3.19.6-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 11.4 MB/s eta 0:00:00
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Downloading tensorboard_data_server-0.6.1-py3-none-manylinux2010_x86_64.whl (4.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 36.5 MB/s eta 0:00:00
# Collecting werkzeug>=1.0.1
#   Downloading Werkzeug-2.2.2-py3-none-any.whl (232 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.7/232.7 kB 20.4 MB/s eta 0:00:00
# Collecting tensorboard-plugin-wit>=1.6.0
#   Downloading tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 781.3/781.3 kB 8.6 MB/s eta 0:00:00
# Collecting markdown>=2.6.8
#   Downloading Markdown-3.4.1-py3-none-any.whl (93 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.3/93.3 kB 8.6 MB/s eta 0:00:00
# Requirement already satisfied: wheel>=0.26 in ./venv/lib/python3.7/site-packages (from tensorboard>=2.9.1->pytorch_lightning->-r requirements.txt (line 13)) (0.37.1)
# Requirement already satisfied: setuptools>=41.0.0 in ./venv/lib/python3.7/site-packages (from tensorboard>=2.9.1->pytorch_lightning->-r requirements.txt (line 13)) (65.3.0)
# Collecting grpcio>=1.24.3
#   Downloading grpcio-1.50.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 33.4 MB/s eta 0:00:00
# Collecting absl-py>=0.4
#   Downloading absl_py-1.3.0-py3-none-any.whl (124 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.6/124.6 kB 12.7 MB/s eta 0:00:00
# Collecting certifi>=2017.4.17
#   Downloading certifi-2022.9.24-py3-none-any.whl (161 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.1/161.1 kB 16.2 MB/s eta 0:00:00
# Collecting idna<4,>=2.5
#   Downloading idna-3.4-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.5/61.5 kB 7.3 MB/s eta 0:00:00
# Collecting charset-normalizer<3,>=2
#   Downloading charset_normalizer-2.1.1-py3-none-any.whl (39 kB)
# Collecting urllib3<1.27,>=1.21.1
#   Downloading urllib3-1.26.12-py2.py3-none-any.whl (140 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.4/140.4 kB 14.9 MB/s eta 0:00:00
# Collecting zipp>=0.5
#   Downloading zipp-3.10.0-py3-none-any.whl (6.2 kB)
# Collecting attrs>=17.4.0
#   Downloading attrs-22.1.0-py2.py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 6.9 MB/s eta 0:00:00
# Collecting pkgutil-resolve-name>=1.3.10
#   Downloading pkgutil_resolve_name-1.3.10-py3-none-any.whl (4.7 kB)
# Collecting pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0
#   Downloading pyrsistent-0.18.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.1/117.1 kB 12.9 MB/s eta 0:00:00
# Collecting importlib-resources>=1.4.0
#   Downloading importlib_resources-5.10.0-py3-none-any.whl (34 kB)
# Collecting joblib
#   Downloading joblib-1.2.0-py3-none-any.whl (297 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.0/298.0 kB 7.3 MB/s eta 0:00:00
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (148 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.0/148.0 kB 15.2 MB/s eta 0:00:00
# Collecting asynctest==0.13.0
#   Downloading asynctest-0.13.0-py3-none-any.whl (26 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (94 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.8/94.8 kB 8.8 MB/s eta 0:00:00
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.8.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (231 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 231.3/231.3 kB 18.9 MB/s eta 0:00:00
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.2.0-py3-none-any.whl (8.2 kB)
# Collecting sniffio>=1.1
#   Downloading sniffio-1.3.0-py3-none-any.whl (10 kB)
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Collecting cachetools<6.0,>=2.0.0
#   Downloading cachetools-5.2.0-py3-none-any.whl (9.3 kB)
# Collecting six>=1.9.0
#   Downloading six-1.16.0-py2.py3-none-any.whl (11 kB)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 12.4 MB/s eta 0:00:00
# Collecting requests-oauthlib>=0.7.0
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Collecting MarkupSafe>=2.1.1
#   Downloading MarkupSafe-2.1.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Collecting pyasn1<0.5.0,>=0.4.6
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.1/77.1 kB 8.7 MB/s eta 0:00:00
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.7/151.7 kB 15.8 MB/s eta 0:00:00
# Building wheels for collected packages: antlr4-python3-runtime, sentence_transformers, jsonmerge
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144554 sha256=7c4674098aeba35926720bb1dcc2679f4bee15f233893bcb55d22c462566bfd3
#   Stored in directory: /root/.cache/pip/wheels/8b/8d/53/2af8772d9aec614e3fc65e53d4a993ad73c61daa8bbd85a873
#   Building wheel for sentence_transformers (setup.py) ... done
#   Created wheel for sentence_transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125925 sha256=7f561ecbbaaef17da4a27d6798fbe76a5bd76e2c2be7ef27bd905627f45644c9
#   Stored in directory: /root/.cache/pip/wheels/bf/06/fb/d59c1e5bd1dac7f6cf61ec0036cc3a10ab8fecaa6b2c3d3ee9
#   Building wheel for jsonmerge (setup.py) ... done
#   Created wheel for jsonmerge: filename=jsonmerge-1.8.0-py3-none-any.whl size=17987 sha256=ad12b24179b552fcbfe08982362e70eb71427a4cb70b2e5b19ed75fa6011ffc2
#   Stored in directory: /root/.cache/pip/wheels/2f/c8/79/83ddc70e0b20f2df3bbac658c2c5d665b76cedd02e67bd61dc
# Successfully built antlr4-python3-runtime sentence_transformers jsonmerge
# Installing collected packages: wcwidth, tokenizers, tensorboard-plugin-wit, sentencepiece, pyasn1, faiss-cpu, dotmap, antlr4-python3-runtime, zipp, urllib3, typing-extensions, tqdm, threadpoolctl, tensorboard-data-server, sniffio, six, rsa, regex, PyYAML, pyrsistent, pyparsing, pyDeprecate, pyasn1-modules, protobuf, pkgutil-resolve-name, pillow, oauthlib, numpy, networkx, multidict, MarkupSafe, joblib, idna, ftfy, fsspec, frozenlist, filelock, einops, charset-normalizer, certifi, cachetools, attrs, asynctest, absl-py, yarl, werkzeug, torch, tifffile, scipy, requests, PyWavelets, pydantic, packaging, omegaconf, importlib-resources, importlib-metadata, imageio, h11, grpcio, google-auth, async-timeout, anyio, aiosignal, torchvision, torchmetrics, torchdiffeq, torchaudio, starlette, scikit-learn, scikit-image, requests-oauthlib, markdown, jsonschema, huggingface-hub, click, aiohttp, uvicorn, transformers, nltk, jsonmerge, google-auth-oauthlib, fastapi, tensorboard, sentence_transformers, pytorch_lightning

# %%
#@title ### 2. Setup NovelAI

# %cd /content/naifu
# !sed -i 's/# export SAVE_FILES="1"/export SAVE_FILES="1"/g' run.sh
# !bash run.sh & cloudflared tunnel --url localhost:6969
